# %%
import gzip

# %%
EMNIST_PATH = './emnist/'
EMNIST_FILE_NAME = 'emnist-byclass-train-labels-idx1-ubyte'

# %%
with open(EMNIST_PATH + EMNIST_FILE_NAME, "rb") as f:
    data = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-6816671d3d56> in <module>
# ----> 1 with open(EMNIST_PATH + EMNIST_FILE_NAME, "rb") as f:
#       2     data = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: './emnist/emnist-byclass-train-labels-idx1-ubyte'

# %%
data
# Out:
# b'\x00\x00\x08\x01\x00\n\xa6L#$\x06\x03\x16&\x05\t/\x04\x078\x1d(7\x0679+\x06\x03\x07 \x03(\t\x16\x0f\x1a\x02\x05\x02\x0f(\x1c\x058\x08\x161\x0c\t\x01;\x01\x05/1\x06\x12\x01)1\t\x06\x02\t\t\x02\x00.7\x017\x17\x053\x18\x07\x01\x1f\t\x18\x02\x01-\x02\x0f\x02\x04\'\x08\x04\x01\'\t\x03+\x1c\'\x08&\x07\x07&\x02\x041\x04\x04\x04\x0b6\x077\x12#\x05\x02\x13\x14\x01\x08(=\x06\x04;\x18\'($/\t\t\x1c\x07\x19\x0c%4\x13\x06\x16\x06\x18\x01\x1f\x03\x0c\x02\x16:\x18\x12\x12\x05\x0e\x04" \x1c\x05\x03%\x07\x05\t\x16\t\x05\t7\x03\x06\x00\x1e\x1b7\x10\x08\x02+\x00\x069\t\x0e\x021\x1b\t\x18\x03\x0f\x00\x16\x07\x05$\x01\x02\x02\x05\x02\'\x02\x04\x08711%!\x03\t\x02\t7\x02\x00\x00\x02\x081&\x08\x15\x02#\t\x027/\x03\x16\x05 <\x01\x07\x04\x02\x06.\x05\x010\x1d\x1b+\x04\x18\x05\x0e4\x01\x16\x04\x07\x05\x0c\x06\x01\x06\x16\x07/\x08$\x175\x1c/\x03\x01\x19\x04\x1c\x1d\x0c\x19\x05\x1d\x07\x02\r\x06\x00/\x05\x1d\x00\x05\x08\x051\x17\x02\r\x1c7\x02\x18\x1e5\x0f!\x03\'\x0f\x0c\x01\r\x06\r1\x06&\n\x01\x067\x05\x03\x02
# ...
